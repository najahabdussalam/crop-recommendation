# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
df = pd.read_csv('To_Use_data.csv')
df.head(10)
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  79  34  37    20.879744  82.002744  6.502985  202.935536  rice
# 1  78  21  20    21.770462  80.319644  7.038096  226.655537  rice
# 2  92  31  34    23.004459  82.320763  7.840207  263.964248  rice
# 3  98  38  45    26.491096  80.158363  6.980401  242.864034  rice
# 4  79  53  43    20.130175  81.604873  7.628473  262.717340  rice
# 5  65  50  36    23.058049  83.370118  7.073454  251.055000  rice
# 6  75  23  28    22.708838  82.639414  5.700806  271.324860  rice
# 7  95  35  21    20.277744  82.894086  5.718627  241.974195  rice
# 8  92  30  25    24.515881  83.535216  6.685346  230.446236  rice
# 9  69  35  60    23.223974  83.033227  6.336254  221.209196  rice

# %%
df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
df.shape
# Out:
# (2200, 8)

# %%
df['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
df['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %%
df['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
labels = ['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
       'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
       'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
       'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee']
labels_map = {labels[i]:i+1 for i in range(len(labels))}
labels_map
# Out:
# {'rice': 1,
#  'maize': 2,
#  'chickpea': 3,
#  'kidneybeans': 4,
#  'pigeonpeas': 5,
#  'mothbeans': 6,
#  'mungbean': 7,
#  'blackgram': 8,
#  'lentil': 9,
#  'pomegranate': 10,
#  'banana': 11,
#  'mango': 12,
#  'grapes': 13,
#  'watermelon': 14,
#  'muskmelon': 15,
#  'apple': 16,
#  'orange': 17,
#  'papaya': 18,
#  'coconut': 19,
#  'cotton': 20,
#  'jute': 21,
#  'coffee': 22}

# %%
dummm = df.copy()
df['label'] = df['label'].map(labels_map)
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall  label
# 0  79  34  37    20.879744  82.002744  6.502985  202.935536      1
# 1  78  21  20    21.770462  80.319644  7.038096  226.655537      1
# 2  92  31  34    23.004459  82.320763  7.840207  263.964248      1
# 3  98  38  45    26.491096  80.158363  6.980401  242.864034      1
# 4  79  53  43    20.130175  81.604873  7.628473  262.717340      1

# %%
sn.set_palette('Set3')
plt.figure(figsize=(16,9))
sn.countplot(data=df,x = 'label')
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
import scipy.stats as stats

# %%
def visualise(df,col):
    plt.figure(figsize=(15,7))
    plt.subplot(1,3,1)
    plt.hist(df[col],color = 'pink')

    plt.subplot(1,3,2)
    stats.probplot(df[col],dist='norm',plot=plt)

    plt.subplot(1,3,3)
    sn.boxplot(df[col],color = 'pink')

    plt.show()

# %%
for i in df.columns[:-1]:
    print(f' Statistical plots for : {i} is shown ↓')
    visualise(df,i)
    print("-"*60)
# Out:
#  Statistical plots for : N is shown ↓
# ------------------------------------------------------------
#  Statistical plots for : P is shown ↓
# ------------------------------------------------------------
#  Statistical plots for : K is shown ↓
# ------------------------------------------------------------
#  Statistical plots for : temperature is shown ↓
# ------------------------------------------------------------
#  Statistical plots for : humidity is shown ↓
# ------------------------------------------------------------
#  Statistical plots for : ph is shown ↓
# ------------------------------------------------------------
#  Statistical plots for : rainfall is shown ↓
# ------------------------------------------------------------

# %% [raw]
# def quantile(df,val):
#     a = []
#     df_25 = df[val].quantile(0.25)
#     df_75 = df[val].quantile(0.75)
#     iqr = df_75-df_25
#     upper_limit = float(df_75+(iqr*1.5))
#     lower_limit = float(df_25-(iqr*1.5))
#     for i in df[val]:
#         if i>upper_limit:
#             i = np.NaN
#         elif i<lower_limit:
#             i = np.NaN
#         else:
#             i = i
#         a.append(i)
#     return a

# %% [markdown]
# ## Outlier Removal

# %% [markdown]
# ### First Lets detect the outliers as shown ↓
#
# **We will be using the gaussian trainsformation technique which says if there are datapoints greater than "mean+{num} * std",then there is a possibilty that that particular datapoint will not fit in the gaussian distribution,so here i have choosen the num as 3,so my range is {lower,upper} = {mean-{3} * std,mean+{3} * std},if there are any datapoints beyond these ranges,then they must be removed,so we find there are couple of data points of that,inorder to remove these outilers,we will be using another method of `Quantiles` which is `Inter Quantile Range` which is a better approach!**

# %%
temp = df.copy()

# %%
upper_list = []
lower_list = []

for i in temp.columns[:-1]:
    upper_list.append(df[i].mean()+(df[i].std())*3)
    lower_list.append(df[i].mean()-(df[i].std())*3)

# %%
j = 0
for i in temp.columns[:-1]:
    dummy = temp[(temp[i]>upper_list[j])|(temp[i]<lower_list[j])];j+=1

# %%
dummy
# Out:
#       N   P   K  temperature   humidity        ph    rainfall  label
# 6    75  23  28    22.708838  82.639414  5.700806  271.324860      1
# 12   86  52  48    26.800796  80.886848  5.108682  284.436457      1
# 16   61  46  51    21.587118  82.788371  6.249051  276.655246      1
# 19  100  46  34    23.579436  83.587603  5.853932  291.298662      1
# 26   96  32  31    26.359272  84.044036  6.286500  271.358614      1
# 30   68  34  49    21.446540  84.943760  5.824709  272.201720      1
# 33   94  25  30    20.267076  81.638952  5.014507  270.441727      1
# 36   78  23  40    26.757542  81.177340  5.960370  272.299906      1
# 37   74  42  29    23.863305  83.152508  5.561399  285.249365      1
# 38   68  60  49    21.019447  82.952217  7.416245  298.401847      1
# 43   83  44  50    23.830675  84.813601  6.271479  298.560117      1
# 54   73  30  40    26.229169  83.836258  5.543360  286.508373      1
# 55   78  34  25    23.446768  84.793524  6.215110  283.933847      1
# 59   93  39  39    21.723831  80.238990  6.501698  277.962619      1
# 62   71  31  52    20.615214  83.773456  6.932400  279.545172      1
# 69  100  57  31    23.431916  80.568878  6.363472  269.503916      1
# 72   64  33  26    24.873007  82.840226  6.587919  295.609449      1
# 75   99  51  39    22.228698  81.858729  6.939084  278.079179      1
# 76   77  41  44    26.730724  81.785968  7.868475  280.404439      1
# 90   81  30  26    26.929951  81.914112  7.069172  290.679378      1
# 96   81  35  40    21.533463  82.140041  6.500343  295.924880      1
# 97   90  22  42    21.408658  83.329319  5.935745  287.576693      1

# %% [markdown]
# ## Outlier Removal using IQR technique

# %%
def quantile(df,val):
    a = []
    df_upper_limit = df[val].quantile(0.75)
    df_lower_limit = df[val].quantile(0.25)
    iqr = df_upper_limit-df_lower_limit
    upper_limit = float(df_upper_limit+(iqr)*1.5)
    lower_limit = float(df_lower_limit-(iqr)*1.5)

    for i in df[val]:
        if i>upper_limit:
            i = np.NaN

        elif i<lower_limit:
            i = np.NaN

        else:
            i = i

        a.append(i)

    return a

# %%
df.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
temp = df.copy()
temp['N'] = quantile(temp,'N')
temp['P'] = quantile(temp,'P')
temp['K'] = quantile(temp,'K')
temp['temperature'] = quantile(temp,'temperature')
temp['humidity'] = quantile(temp,'humidity')
temp['ph'] = quantile(temp,'ph')
temp['rainfall'] = quantile(temp,'rainfall')
temp.head()
# Out:
#     N     P     K  temperature   humidity        ph    rainfall  label
# 0  79  34.0  37.0    20.879744  82.002744  6.502985  202.935536      1
# 1  78  21.0  20.0    21.770462  80.319644  7.038096         NaN      1
# 2  92  31.0  34.0    23.004459  82.320763  7.840207         NaN      1
# 3  98  38.0  45.0    26.491096  80.158363  6.980401         NaN      1
# 4  79  53.0  43.0    20.130175  81.604873  7.628473         NaN      1

# %%
temp = temp.dropna()
temp.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
temp.shape
# Out:
# (1766, 8)

# %%
temp.head()
# Out:
#      N     P     K  temperature   humidity        ph    rainfall  label
# 0   79  34.0  37.0    20.879744  82.002744  6.502985  202.935536      1
# 13  86  20.0  31.0    24.014976  82.056872  6.984354  185.277339      1
# 14  75  22.0  56.0    25.665852  80.663850  6.948020  209.586971      1
# 17  69  45.0  28.0    23.793920  80.418180  6.970860  206.261186      1
# 20  62  49.0  37.0    21.325042  80.474764  6.442475  185.497473      1

# %%
for i in temp.columns[:-1]:
    print(f' Statistical plots for {i} is shown ↓')
    visualise(temp,i)
    print("=>"*50)
# Out:
#  Statistical plots for N is shown ↓
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
#  Statistical plots for P is shown ↓
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
#  Statistical plots for K is shown ↓
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
#  Statistical plots for temperature is shown ↓
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
#  Statistical plots for humidity is shown ↓
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
#  Statistical plots for ph is shown ↓
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
#  Statistical plots for rainfall is shown ↓
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>

# %% [markdown]
# **Now we have to see which all values Are not properly normally distributed,well there are few like `N,humidity,rainfall`,as we can observe from the Q-Q plot,they're not that correctly fitted,lets try to fix them a bit**

# %%
data = df.copy()
data['N'],params = stats.boxcox(data['N']+1)
stats.probplot(data['N'],dist='norm',plot=plt)
# Out:
# ((array([-3.41834386, -3.16906693, -3.03090347, ...,  3.03090347,
#           3.16906693,  3.41834386]),
#   array([ 0.        ,  0.        ,  0.        , ..., 15.52214998,
#          15.52214998, 15.52214998])),
#  (3.8370176242457106, 8.60900074072838, 0.9809808425996115))

# %%
data = temp.copy()
data['N'] = data.N**(1/1.2)
stats.probplot(data['N'],dist='norm',plot=plt)
# Out:
# ((array([-3.35808769, -3.10465012, -2.96393634, ...,  2.96393634,
#           3.10465012,  3.35808769]),
#   array([ 0.        ,  0.        ,  0.        , ..., 61.43841876,
#          61.43841876, 61.43841876])),
#  (16.513977488284294, 26.88812089792998, 0.9652035685212719))

# %%
from sklearn.model_selection import train_test_split,RandomizedSearchCV,cross_val_score
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
temp.head(2)
# Out:
#      N     P     K  temperature   humidity        ph    rainfall  label
# 0   79  34.0  37.0    20.879744  82.002744  6.502985  202.935536      1
# 13  86  20.0  31.0    24.014976  82.056872  6.984354  185.277339      1

# %%
test = temp['label']
train = temp.drop(['label'],axis = 1)
X_train, X_test, y_train, y_test = train_test_split(train,test,test_size = 0.2)

# %%
sc = StandardScaler()
train_scaled = sc.fit_transform(X_train)
test_scaled = sc.transform(X_test)

# %%
scaled_df = pd.DataFrame(train_scaled,columns=train.columns)
for i in scaled_df.columns:
    print(f' Statistical plots for {i} is shown ↓')
    visualise(scaled_df,i)
    print("=>"*50)
# Out:
#  Statistical plots for N is shown ↓
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
#  Statistical plots for P is shown ↓
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
#  Statistical plots for K is shown ↓
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
#  Statistical plots for temperature is shown ↓
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
#  Statistical plots for humidity is shown ↓
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
#  Statistical plots for ph is shown ↓
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
#  Statistical plots for rainfall is shown ↓
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>

# %%
scaled_df.head()
# Out:
#           N         P         K  temperature  humidity        ph  rainfall
# 0  1.316041  0.839400  0.350029     0.869786  0.364094 -1.424962  0.003771
# 1 -0.561473 -1.698830  0.825209    -0.629860  1.142625 -0.149095  0.272835
# 2  0.724496  0.557374  0.508422    -0.212870  0.835073  1.124977  1.477879
# 3  1.136005  0.154481 -0.969917     0.049303  0.055654  0.685552  0.089387
# 4  1.213164 -1.376515  0.138837     0.440980  1.006039 -0.175677 -1.607288

# %%
mm = MinMaxScaler()
train_mm = mm.fit_transform(X_train)
test_mm = mm.transform(X_test)

# %%
scaled_mm = pd.DataFrame(train_mm,columns=train.columns)
for i in scaled_mm.columns:
    print(f' Statistical plots for {i} is shown ↓')
    visualise(scaled_mm,i)
    print("=>"*50)
# Out:
#  Statistical plots for N is shown ↓
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
#  Statistical plots for P is shown ↓
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
#  Statistical plots for K is shown ↓
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
#  Statistical plots for temperature is shown ↓
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
#  Statistical plots for humidity is shown ↓
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
#  Statistical plots for ph is shown ↓
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>
#  Statistical plots for rainfall is shown ↓
# =>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>

# %%
scaled_mm.head()
# Out:
#           N         P         K  temperature  humidity        ph  rainfall
# 0  0.755396  0.647619  0.448598     0.658879  0.741457  0.260868  0.407845
# 1  0.230216  0.047619  0.532710     0.380290  0.940178  0.496790  0.475959
# 2  0.589928  0.580952  0.476636     0.457754  0.861675  0.732379  0.781020
# 3  0.705036  0.485714  0.214953     0.506458  0.662727  0.651125  0.429519
# 4  0.726619  0.123810  0.411215     0.579220  0.905314  0.491874  0.000000

# %%
dum = scaled_df.copy()
dum['N'] = np.log(dum['N']+1)
stats.probplot(dum['N'],dist = 'norm',plot=plt)
# Out:
# C:\Users\user2\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ((array([-3.29576125, -3.03787488, -2.89442031, ...,  2.89442031,
#           3.03787488,  3.29576125]),
#   array([-6.64687707, -6.64687707, -6.64687707, ...,         nan,
#                  nan,         nan])),
#  (nan, nan, nan))

# %%
dum = scaled_df.copy()
dum['humidity'] = np.log(dum['humidity']+1)
stats.probplot(dum['humidity'],dist = 'norm',plot=plt)
# Out:
# ((array([-3.29576125, -3.03787488, -2.89442031, ...,  2.89442031,
#           3.03787488,  3.29576125]),
#   array([-7.95912908, -5.88942599, -5.46552729, ...,         nan,
#                  nan,         nan])),
#  (nan, nan, nan))

# %%
X_train_scaled = mm.fit_transform(X_train)
X_test_scaled = mm.fit_transform(X_test)

# %% [markdown]
# ### ML ALGO

# %%
from sklearn.model_selection import RandomizedSearchCV,train_test_split,cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn import metrics
from sklearn.svm import SVC
from sklearn import tree

# %%
X_train_df = pd.DataFrame(X_train_scaled,columns=train.columns)
X_train_df.head()
# Out:
#           N         P         K  temperature  humidity        ph  rainfall
# 0  0.755396  0.647619  0.448598     0.658879  0.741457  0.260868  0.407845
# 1  0.230216  0.047619  0.532710     0.380290  0.940178  0.496790  0.475959
# 2  0.589928  0.580952  0.476636     0.457754  0.861675  0.732379  0.781020
# 3  0.705036  0.485714  0.214953     0.506458  0.662727  0.651125  0.429519
# 4  0.726619  0.123810  0.411215     0.579220  0.905314  0.491874  0.000000

# %%
X_train_scaled
# Out:
# array([[0.75539568, 0.64761905, 0.44859813, ..., 0.74145707, 0.26086818,
#         0.4078447 ],
#        [0.23021583, 0.04761905, 0.53271028, ..., 0.94017791, 0.49678974,
#         0.47595921],
#        [0.58992806, 0.58095238, 0.47663551, ..., 0.86167475, 0.73237945,
#         0.78101986],
#        ...,
#        [0.17266187, 0.12380952, 0.3271028 , ..., 0.36783554, 0.11677384,
#         0.37267041],
#        [0.74820144, 0.31428571, 0.55140187, ..., 0.87204262, 0.50317418,
#         0.2065962 ],
#        [0.8057554 , 0.48571429, 0.39252336, ..., 0.71738685, 0.43085128,
#         0.26274328]])

# %%
clf = DecisionTreeClassifier(random_state=0)
clf.fit(X_train,y_train)
plt.figure(figsize=(16,9))
tree.plot_tree(clf,filled=True,feature_names=train.columns)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[50], line 4
#       2 clf.fit(X_train,y_train)
#       3 plt.figure(figsize=(16,9))
# ----> 4 tree.plot_tree(clf,filled=True,feature_names=train.columns)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:201, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     198 to_ignore += ["self", "cls"]
#     199 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 201 validate_parameter_constraints(
#     202     parameter_constraints, params, caller_name=func.__qualname__
#     203 )
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:95, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      89 else:
#      90     constraints_str = (
#      91         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      92         f" {constraints[-1]}"
#      93     )
# ---> 95 raise InvalidParameterError(
#      96     f"The {param_name!r} parameter of {caller_name} must be"
#      97     f" {constraints_str}. Got {param_val!r} instead."
#      98 )
#
# InvalidParameterError: The 'feature_names' parameter of plot_tree must be an instance of 'list' or None. Got Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall'], dtype='object') instead.

# %%
path = clf.cost_complexity_pruning_path(X_train,y_train)
ccp_alpha = path.ccp_alphas
ccp_alpha
# Out:
# array([0.        , 0.00059018, 0.00069485, 0.00069838, 0.00069998,
#        0.0007554 , 0.00092233, 0.00094429, 0.00106232, 0.0013279 ,
#        0.00133823, 0.0013831 , 0.00139754, 0.00139996, 0.00263902,
#        0.00264121, 0.0027483 , 0.00276698, 0.00292944, 0.00308782,
#        0.00378881, 0.00539268, 0.00609557, 0.00622245, 0.00653828,
#        0.00665552, 0.00667513, 0.00792589, 0.00847425, 0.00956351,
#        0.01470991, 0.01741131, 0.02887423, 0.03415932, 0.03852207,
#        0.03914934, 0.04409846, 0.04927669, 0.05215087, 0.05241452,
#        0.05443138])

# %%
alpha_list = []
for i in ccp_alpha:
    clf = DecisionTreeClassifier(random_state=0,ccp_alpha=i)
    clf.fit(X_train,y_train)
    alpha_list.append(clf)

# %%
train_score = [clf.score(X_train,y_train) for clf in alpha_list]
test_score =  [clf.score(X_test,y_test) for clf in alpha_list]

plt.xlabel('alpha')
plt.ylabel('accuracy')
plt.plot(ccp_alpha,train_score,marker = 'o',label = 'training',color = 'magenta',drawstyle = 'steps-post')
plt.plot(ccp_alpha,test_score,marker = '+',label = 'testing',color = 'red',drawstyle = 'steps-post')
plt.legend()
plt.show()

# %%
clf = DecisionTreeClassifier(random_state=0,ccp_alpha=0.045)
clf.fit(X_train,y_train)
plt.figure(figsize=(16,9))
tree.plot_tree(clf,filled=True,feature_names=train.columns)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[54], line 4
#       2 clf.fit(X_train,y_train)
#       3 plt.figure(figsize=(16,9))
# ----> 4 tree.plot_tree(clf,filled=True,feature_names=train.columns)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:201, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     198 to_ignore += ["self", "cls"]
#     199 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 201 validate_parameter_constraints(
#     202     parameter_constraints, params, caller_name=func.__qualname__
#     203 )
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:95, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      89 else:
#      90     constraints_str = (
#      91         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      92         f" {constraints[-1]}"
#      93     )
# ---> 95 raise InvalidParameterError(
#      96     f"The {param_name!r} parameter of {caller_name} must be"
#      97     f" {constraints_str}. Got {param_val!r} instead."
#      98 )
#
# InvalidParameterError: The 'feature_names' parameter of plot_tree must be an instance of 'list' or None. Got Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall'], dtype='object') instead.

# %%
params = {
    'RandomForest':{
        'model': RandomForestClassifier(),
        'params':{
            'n_estimators': [int(x) for x in np.linspace(start=1,stop=1200,num=10)],
            'max_depth':[int(x) for x in np.linspace(start=1,stop=30,num=5)],
            'min_samples_split':[2,5,10,12],
            'min_samples_leaf':[2,5,10,12],
            'max_features':['auto','sqrt'],
            'ccp_alpha':[0.030,0.035,0.040,0.045,0.050],
        }
    },

    'logistic':{
        'model':LogisticRegression(),
        'params':{
            'penalty':['l1', 'l2', 'elasticnet'],
            'C':[0.25,0.50,0.75,1.0],
            'tol':[1e-10,1e-5,1e-4,1e-3,0.025,0.25,0.50],
            'solver':['lbfgs','liblinear','saga','newton-cg'],
            'multi_class':['auto', 'ovr', 'multinomial'],
            'max_iter':[int(x) for x in np.linspace(start=1,stop=250,num=10)],
        }
    },
    'D-tree':{
        'model':DecisionTreeClassifier(),
        'params':{
            'criterion':['gini','entropy'],
            'splitter':['best','random'],
            'min_samples_split':[1,2,5,10,12],
            'min_samples_leaf':[1,2,5,10,12],
            'max_features':['auto','sqrt'],
            'ccp_alpha':[0.030,0.035,0.040,0.045,0.050],
        }
    },
    'SVM':{
        'model':SVC(),
        'params':{
            'C':[0.25,0.50,0.75,1.0],
            'tol':[1e-10,1e-5,1e-4,0.025,0.50,0.75],
            'kernel':['linear','poly','sigmoid','rbf'],
            'max_iter':[int(x) for x in np.linspace(start=1,stop=250,num=10)],
        }
    }
}

# %%
scores = []
for model_name,mp in params.items():
    clf = RandomizedSearchCV(mp['model'],param_distributions= mp['params'],cv = 5,n_jobs=-1,n_iter = 10,scoring='accuracy',
                            verbose=2)
    clf.fit(X_train,y_train)
    scores.append({
        'model_name':model_name,
        'best_score':clf.best_score_,
        'best_estimator':clf.best_estimator_
    })
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 15 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [0.52126908 0.82224645 0.82366489 0.77976844 0.88102398 0.85835902
#  0.34555046        nan        nan        nan]
#   warnings.warn(
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 15 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1168, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1168, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 66, in _check_solver
#     raise ValueError(
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [0.79176754        nan        nan 0.89518833 0.84985841 0.95537929
#         nan 0.87394431 0.72306343 0.7995865 ]
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\utils\optimize.py:211: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 35 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\user2\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of DecisionTreeClassifier must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan 0.12670977        nan        nan        nan 0.42621858
#         nan 0.39889733        nan        nan]
#   warnings.warn(
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Fitting 5 folds for each of 10 candidates, totalling 50 fits

# %%
scores_df = pd.DataFrame(data = scores,columns = ['model_name','best_estimator','best_score'])
scores_df
# Out:
#      model_name                                     best_estimator  best_score
# 0  RandomForest  (DecisionTreeClassifier(ccp_alpha=0.035, max_d...    0.881024
# 1      logistic  LogisticRegression(C=0.75, max_iter=194, multi...    0.955379
# 2        D-tree  DecisionTreeClassifier(ccp_alpha=0.05, criteri...    0.426219
# 3           SVM          SVC(kernel='poly', max_iter=167, tol=0.5)    0.952532

# %%
for i in scores_df['best_estimator']:
    print(i)
# Out:
# RandomForestClassifier(ccp_alpha=0.035, max_depth=8, min_samples_leaf=10,
#                        min_samples_split=5, n_estimators=533)
# LogisticRegression(C=0.75, max_iter=194, multi_class='multinomial',
#                    solver='newton-cg', tol=0.001)
# DecisionTreeClassifier(ccp_alpha=0.05, criterion='entropy', max_features='sqrt',
#                        min_samples_leaf=12, min_samples_split=5,
#                        splitter='random')
# SVC(kernel='poly', max_iter=167, tol=0.5)

# %%
rf = RandomForestClassifier(ccp_alpha=0.03, max_depth=22, min_samples_leaf=12,
                       min_samples_split=5, n_estimators=800)

lr = LogisticRegression(C=0.75, max_iter=194, multi_class='ovr', penalty='l1',
                   solver='liblinear')

svc = SVC(C=0.5, kernel='poly', max_iter=139, tol=1e-10)

rf_val = cross_val_score(estimator=rf,X=X_train_scaled,y=y_train,cv=20,n_jobs=-1)
lr_val = cross_val_score(estimator = lr,X=X_train_scaled,y=y_train,cv=20,n_jobs=-1)
svc_val = cross_val_score(estimator=svc,X=X_train_scaled,y=y_train,cv=20,n_jobs=-1)

# %%
score_list = [rf_val,lr_val,svc_val]
model_name = ['rf','lr','svc']
for i,j in zip(score_list,model_name):
    print(f' Model : {j} gave {i.mean()} accuracy')
# Out:
#  Model : rf gave 0.8930482897384305 accuracy
#  Model : lr gave 0.9000704225352113 accuracy
#  Model : svc gave 0.970241448692153 accuracy

# %%
from sklearn import metrics

# %%
svc = SVC(C=0.5, kernel='poly', max_iter=139, tol=1e-10)
svc.fit(X_train_scaled,y_train)
svc.score(X_train_scaled,y_train)
# Out:
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=139).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# 0.9858356940509915

# %%
rf = RandomForestClassifier(ccp_alpha=0.03, max_depth=22, min_samples_leaf=12,
                       min_samples_split=5, n_estimators=800)

rf.fit(X_train,y_train)
rf.score(X_train,y_train)
# Out:
# 0.896600566572238

# %%
svc = SVC(C=0.5, kernel='poly', max_iter=139, tol=1e-10)
svc.fit(X_train,y_train)
svc.score(X_train,y_train)
# Out:
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=139).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# 0.9674220963172805

# %%
svc.score(X_test,y_test)
# Out:
# 0.96045197740113

# %%
y_pred = svc.predict(X_test)
cn = metrics.confusion_matrix(y_test,y_pred)
plt.figure(figsize=(16,9))
sn.heatmap(cn,annot=True,linecolor='red',linewidths=2,cmap='plasma')
# Out:
# <Axes: >

# %%
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.67      0.57      0.62         7
#            2       0.94      0.94      0.94        16
#            3       1.00      1.00      1.00        13
#            4       1.00      1.00      1.00        26
#            5       1.00      1.00      1.00        15
#            6       0.92      0.92      0.92        13
#            7       1.00      1.00      1.00        18
#            8       0.88      1.00      0.94        15
#            9       1.00      0.94      0.97        16
#           10       0.79      1.00      0.88        15
#           11       1.00      1.00      1.00        25
#           12       1.00      1.00      1.00        19
#           14       1.00      1.00      1.00        21
#           15       1.00      1.00      1.00        23
#           17       1.00      0.82      0.90        22
#           18       1.00      0.83      0.91         6
#           19       0.93      1.00      0.97        14
#           20       1.00      1.00      1.00        25
#           21       0.88      0.91      0.89        23
#           22       1.00      0.95      0.98        22
#
#     accuracy                           0.96       354
#    macro avg       0.95      0.94      0.95       354
# weighted avg       0.96      0.96      0.96       354

# %%
train.shape,temp.shape
# Out:
# ((1766, 7), (1766, 8))

# %%
train = np.array(train)
predict_list = []
for i in range(0,len(train)):
    predict_list.append(svc.predict([train[i]]))
# Out:
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
predict_list = np.array(predict_list)

# %%
temp.head()
# Out:
#      N     P     K  temperature   humidity        ph    rainfall  label
# 0   79  34.0  37.0    20.879744  82.002744  6.502985  202.935536      1
# 13  86  20.0  31.0    24.014976  82.056872  6.984354  185.277339      1
# 14  75  22.0  56.0    25.665852  80.663850  6.948020  209.586971      1
# 17  69  45.0  28.0    23.793920  80.418180  6.970860  206.261186      1
# 20  62  49.0  37.0    21.325042  80.474764  6.442475  185.497473      1

# %%
original_labels = ['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
       'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
       'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
       'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee']
labels_map_new = {i+1:original_labels[i] for i in range(len(original_labels))}
labels_map_new
# Out:
# {1: 'rice',
#  2: 'maize',
#  3: 'chickpea',
#  4: 'kidneybeans',
#  5: 'pigeonpeas',
#  6: 'mothbeans',
#  7: 'mungbean',
#  8: 'blackgram',
#  9: 'lentil',
#  10: 'pomegranate',
#  11: 'banana',
#  12: 'mango',
#  13: 'grapes',
#  14: 'watermelon',
#  15: 'muskmelon',
#  16: 'apple',
#  17: 'orange',
#  18: 'papaya',
#  19: 'coconut',
#  20: 'cotton',
#  21: 'jute',
#  22: 'coffee'}

# %%
temp['Original_labels'] = temp['label'].map(labels_map_new)
temp.head()
# Out:
#      N     P     K  temperature   humidity        ph    rainfall  label  \
# 0   79  34.0  37.0    20.879744  82.002744  6.502985  202.935536      1
# 13  86  20.0  31.0    24.014976  82.056872  6.984354  185.277339      1
# 14  75  22.0  56.0    25.665852  80.663850  6.948020  209.586971      1
# 17  69  45.0  28.0    23.793920  80.418180  6.970860  206.261186      1
# 20  62  49.0  37.0    21.325042  80.474764  6.442475  185.497473      1
#
#    Original_labels
# 0             rice
# 13            rice
# 14            rice
# 17            rice
# 20            rice

# %%
temp['SVM_pred'] = predict_list

# %%
temp['Predicted_labels'] = temp['SVM_pred'].map(labels_map_new)
temp.head()
# Out:
#      N     P     K  temperature   humidity        ph    rainfall  label  \
# 0   79  34.0  37.0    20.879744  82.002744  6.502985  202.935536      1
# 13  86  20.0  31.0    24.014976  82.056872  6.984354  185.277339      1
# 14  75  22.0  56.0    25.665852  80.663850  6.948020  209.586971      1
# 17  69  45.0  28.0    23.793920  80.418180  6.970860  206.261186      1
# 20  62  49.0  37.0    21.325042  80.474764  6.442475  185.497473      1
#
#    Original_labels  SVM_pred Predicted_labels
# 0             rice         1             rice
# 13            rice         1             rice
# 14            rice         1             rice
# 17            rice         1             rice
# 20            rice        21             jute

# %%
plt.figure(figsize=(25,10))
sn.countplot(data=temp,x = 'Original_labels')
# Out:
# <Axes: xlabel='Original_labels', ylabel='count'>

# %%
plt.figure(figsize=(25,10))
sn.countplot(data = temp,x = 'Predicted_labels')
# Out:
# <Axes: xlabel='Predicted_labels', ylabel='count'>

# %%
temp['Predicted_labels'].value_counts()
# Out:
# Predicted_labels
# pomegranate    109
# blackgram      107
# lentil         104
# jute           103
# kidneybeans    102
# banana         101
# watermelon     101
# muskmelon      100
# mungbean       100
# cotton          99
# mango           99
# maize           97
# coffee          96
# pigeonpeas      95
# coconut         86
# orange          74
# chickpea        56
# papaya          54
# mothbeans       52
# rice            31
# Name: count, dtype: int64

# %%
temp['Original_labels'].value_counts()
# Out:
# Original_labels
# banana         100
# lentil         100
# jute           100
# cotton         100
# muskmelon      100
# watermelon     100
# maize          100
# pomegranate    100
# coffee         100
# blackgram      100
# mungbean       100
# pigeonpeas     100
# kidneybeans    100
# mango           98
# coconut         85
# orange          83
# mothbeans       58
# chickpea        56
# papaya          54
# rice            32
# Name: count, dtype: int64

# %%
a = temp[temp['Original_labels']!=temp['Predicted_labels']].style.background_gradient('plasma')
a
# Out:
# <style type="text/css">
# #T_61e75_row0_col0 {
#   background-color: #e56a5d;
#   color: #f1f1f1;
# }
# #T_61e75_row0_col1, #T_61e75_row1_col1, #T_61e75_row9_col2, #T_61e75_row14_col3, #T_61e75_row17_col1 {
#   background-color: #e76f5a;
#   color: #f1f1f1;
# }
# #T_61e75_row0_col2, #T_61e75_row53_col3 {
#   background-color: #e4695e;
#   color: #f1f1f1;
# }
# #T_61e75_row0_col3, #T_61e75_row32_col5, #T_61e75_row39_col0 {
#   background-color: #9a169f;
#   color: #f1f1f1;
# }
# #T_61e75_row0_col4, #T_61e75_row1_col4, #T_61e75_row5_col4 {
#   background-color: #fca934;
#   color: #000000;
# }
# #T_61e75_row0_col5, #T_61e75_row2_col3, #T_61e75_row24_col4 {
#   background-color: #ce4b75;
#   color: #f1f1f1;
# }
# #T_61e75_row0_col6, #T_61e75_row17_col3 {
#   background-color: #fada24;
#   color: #000000;
# }
# #T_61e75_row0_col7, #T_61e75_row1_col7, #T_61e75_row2_col7, #T_61e75_row3_col7, #T_61e75_row4_col7, #T_61e75_row5_col7, #T_61e75_row6_col7, #T_61e75_row7_col7, #T_61e75_row12_col4, #T_61e75_row18_col2, #T_61e75_row19_col6, #T_61e75_row28_col5, #T_61e75_row30_col2, #T_61e75_row32_col1, #T_61e75_row35_col3, #T_61e75_row38_col0, #T_61e75_row48_col9, #T_61e75_row49_col9, #T_61e75_row50_col9, #T_61e75_row51_col9, #T_61e75_row52_col9, #T_61e75_row53_col9, #T_61e75_row55_col9 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# #T_61e75_row0_col9, #T_61e75_row1_col9, #T_61e75_row2_col6, #T_61e75_row2_col9, #T_61e75_row3_col2, #T_61e75_row3_col9, #T_61e75_row4_col9, #T_61e75_row5_col9, #T_61e75_row6_col2, #T_61e75_row6_col9, #T_61e75_row7_col9, #T_61e75_row8_col0, #T_61e75_row15_col1, #T_61e75_row22_col5, #T_61e75_row31_col4, #T_61e75_row43_col3, #T_61e75_row47_col0, #T_61e75_row49_col6, #T_61e75_row50_col6, #T_61e75_row55_col0, #T_61e75_row56_col7, #T_61e75_row56_col9, #T_61e75_row57_col7, #T_61e75_row58_col7, #T_61e75_row58_col9, #T_61e75_row59_col7, #T_61e75_row59_col9 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_61e75_row1_col0 {
#   background-color: #feb72d;
#   color: #000000;
# }
# #T_61e75_row1_col2, #T_61e75_row10_col5, #T_61e75_row22_col2, #T_61e75_row58_col1 {
#   background-color: #cf4c74;
#   color: #f1f1f1;
# }
# #T_61e75_row1_col3, #T_61e75_row4_col3, #T_61e75_row33_col5, #T_61e75_row46_col3 {
#   background-color: #cd4a76;
#   color: #f1f1f1;
# }
# #T_61e75_row1_col5, #T_61e75_row8_col6, #T_61e75_row31_col7, #T_61e75_row32_col7, #T_61e75_row33_col7, #T_61e75_row50_col5, #T_61e75_row51_col5 {
#   background-color: #b83289;
#   color: #f1f1f1;
# }
# #T_61e75_row1_col6, #T_61e75_row5_col0, #T_61e75_row7_col6, #T_61e75_row58_col0 {
#   background-color: #fbd724;
#   color: #000000;
# }
# #T_61e75_row2_col0, #T_61e75_row2_col1, #T_61e75_row20_col1 {
#   background-color: #f79143;
#   color: #f1f1f1;
# }
# #T_61e75_row2_col2, #T_61e75_row50_col2 {
#   background-color: #fa9b3d;
#   color: #000000;
# }
# #T_61e75_row2_col4, #T_61e75_row37_col5 {
#   background-color: #febe2a;
#   color: #000000;
# }
# #T_61e75_row2_col5 {
#   background-color: #5c01a6;
#   color: #f1f1f1;
# }
# #T_61e75_row3_col0, #T_61e75_row19_col5 {
#   background-color: #f1f525;
#   color: #000000;
# }
# #T_61e75_row3_col1, #T_61e75_row45_col6 {
#   background-color: #ca457a;
#   color: #f1f1f1;
# }
# #T_61e75_row3_col3, #T_61e75_row39_col6, #T_61e75_row51_col3 {
#   background-color: #c9447a;
#   color: #f1f1f1;
# }
# #T_61e75_row3_col4 {
#   background-color: #fdb52e;
#   color: #000000;
# }
# #T_61e75_row3_col5, #T_61e75_row7_col3, #T_61e75_row43_col5, #T_61e75_row57_col4, #T_61e75_row59_col5 {
#   background-color: #e06363;
#   color: #f1f1f1;
# }
# #T_61e75_row3_col6, #T_61e75_row5_col6, #T_61e75_row6_col6, #T_61e75_row48_col4 {
#   background-color: #fbd324;
#   color: #000000;
# }
# #T_61e75_row4_col0, #T_61e75_row41_col5 {
#   background-color: #fdc627;
#   color: #000000;
# }
# #T_61e75_row4_col1, #T_61e75_row24_col5, #T_61e75_row26_col4, #T_61e75_row48_col1 {
#   background-color: #bb3488;
#   color: #f1f1f1;
# }
# #T_61e75_row4_col2, #T_61e75_row18_col4, #T_61e75_row28_col4, #T_61e75_row56_col5 {
#   background-color: #d35171;
#   color: #f1f1f1;
# }
# #T_61e75_row4_col4 {
#   background-color: #fdb130;
#   color: #000000;
# }
# #T_61e75_row4_col5, #T_61e75_row15_col0 {
#   background-color: #46039f;
#   color: #f1f1f1;
# }
# #T_61e75_row4_col6 {
#   background-color: #f9dc24;
#   color: #000000;
# }
# #T_61e75_row5_col1, #T_61e75_row11_col4, #T_61e75_row57_col6 {
#   background-color: #d24f71;
#   color: #f1f1f1;
# }
# #T_61e75_row5_col2, #T_61e75_row44_col2 {
#   background-color: #c33d80;
#   color: #f1f1f1;
# }
# #T_61e75_row5_col3, #T_61e75_row22_col4 {
#   background-color: #db5c68;
#   color: #f1f1f1;
# }
# #T_61e75_row5_col5 {
#   background-color: #920fa3;
#   color: #f1f1f1;
# }
# #T_61e75_row6_col0, #T_61e75_row44_col5, #T_61e75_row50_col0 {
#   background-color: #fcd225;
#   color: #000000;
# }
# #T_61e75_row6_col1, #T_61e75_row8_col5, #T_61e75_row37_col1, #T_61e75_row47_col1, #T_61e75_row51_col2 {
#   background-color: #a62098;
#   color: #f1f1f1;
# }
# #T_61e75_row6_col3, #T_61e75_row13_col1, #T_61e75_row55_col1 {
#   background-color: #d5536f;
#   color: #f1f1f1;
# }
# #T_61e75_row6_col4, #T_61e75_row56_col6 {
#   background-color: #fdae32;
#   color: #000000;
# }
# #T_61e75_row6_col5 {
#   background-color: #a82296;
#   color: #f1f1f1;
# }
# #T_61e75_row7_col0, #T_61e75_row38_col5, #T_61e75_row54_col9 {
#   background-color: #feba2c;
#   color: #000000;
# }
# #T_61e75_row7_col1, #T_61e75_row19_col1, #T_61e75_row22_col1, #T_61e75_row27_col1 {
#   background-color: #f89540;
#   color: #000000;
# }
# #T_61e75_row7_col2, #T_61e75_row25_col2, #T_61e75_row38_col2, #T_61e75_row52_col3 {
#   background-color: #ba3388;
#   color: #f1f1f1;
# }
# #T_61e75_row7_col4, #T_61e75_row23_col5, #T_61e75_row52_col2 {
#   background-color: #fec029;
#   color: #000000;
# }
# #T_61e75_row7_col5, #T_61e75_row9_col0 {
#   background-color: #f0804e;
#   color: #f1f1f1;
# }
# #T_61e75_row8_col1 {
#   background-color: #f1814d;
#   color: #f1f1f1;
# }
# #T_61e75_row8_col2, #T_61e75_row18_col9, #T_61e75_row25_col4, #T_61e75_row28_col2 {
#   background-color: #d6556d;
#   color: #f1f1f1;
# }
# #T_61e75_row8_col3, #T_61e75_row36_col0, #T_61e75_row45_col1, #T_61e75_row49_col1 {
#   background-color: #9e199d;
#   color: #f1f1f1;
# }
# #T_61e75_row8_col4 {
#   background-color: #f07f4f;
#   color: #f1f1f1;
# }
# #T_61e75_row8_col7, #T_61e75_row9_col7, #T_61e75_row10_col7, #T_61e75_row11_col7, #T_61e75_row16_col2, #T_61e75_row29_col2, #T_61e75_row41_col1, #T_61e75_row57_col9 {
#   background-color: #2a0593;
#   color: #f1f1f1;
# }
# #T_61e75_row8_col9, #T_61e75_row18_col3, #T_61e75_row30_col3, #T_61e75_row39_col2 {
#   background-color: #cc4778;
#   color: #f1f1f1;
# }
# #T_61e75_row9_col1, #T_61e75_row21_col1, #T_61e75_row22_col3, #T_61e75_row54_col6 {
#   background-color: #f48948;
#   color: #f1f1f1;
# }
# #T_61e75_row9_col3, #T_61e75_row36_col2, #T_61e75_row39_col3, #T_61e75_row40_col2 {
#   background-color: #b52f8c;
#   color: #f1f1f1;
# }
# #T_61e75_row9_col4 {
#   background-color: #d8576b;
#   color: #f1f1f1;
# }
# #T_61e75_row9_col5, #T_61e75_row27_col0 {
#   background-color: #8f0da4;
#   color: #f1f1f1;
# }
# #T_61e75_row9_col6, #T_61e75_row14_col7, #T_61e75_row15_col7, #T_61e75_row16_col7, #T_61e75_row17_col7, #T_61e75_row18_col7 {
#   background-color: #6600a7;
#   color: #f1f1f1;
# }
# #T_61e75_row9_col9, #T_61e75_row10_col9, #T_61e75_row11_col9, #T_61e75_row18_col5, #T_61e75_row20_col9, #T_61e75_row21_col9, #T_61e75_row22_col9, #T_61e75_row23_col9, #T_61e75_row31_col2, #T_61e75_row43_col0, #T_61e75_row57_col2 {
#   background-color: #a11b9b;
#   color: #f1f1f1;
# }
# #T_61e75_row10_col0 {
#   background-color: #e87059;
#   color: #f1f1f1;
# }
# #T_61e75_row10_col1 {
#   background-color: #eb7655;
#   color: #f1f1f1;
# }
# #T_61e75_row10_col2, #T_61e75_row16_col0, #T_61e75_row16_col3, #T_61e75_row21_col6 {
#   background-color: #6300a7;
#   color: #f1f1f1;
# }
# #T_61e75_row10_col3 {
#   background-color: #d04d73;
#   color: #f1f1f1;
# }
# #T_61e75_row10_col4, #T_61e75_row14_col1, #T_61e75_row25_col1, #T_61e75_row50_col1, #T_61e75_row54_col0 {
#   background-color: #e3685f;
#   color: #f1f1f1;
# }
# #T_61e75_row10_col6, #T_61e75_row14_col4 {
#   background-color: #6400a7;
#   color: #f1f1f1;
# }
# #T_61e75_row11_col0, #T_61e75_row14_col2, #T_61e75_row36_col5, #T_61e75_row47_col9 {
#   background-color: #ea7457;
#   color: #f1f1f1;
# }
# #T

# %%
tru = temp['Original_labels'].values
tru = list(tru.flatten())
predict = temp['Predicted_labels'].values
predict = list(predict.flatten())

# %%
count = 0
for i,j in zip(tru,predict):
    if i!=j:

        count+=1

# %%
print(f'Total Values after Preprocessing : {temp.shape[0]}\nMisclassified values are : {temp.shape[0]-count}')
# Out:
# Total Values after Preprocessing : 1766
# Misclassified values are : 1706

# %%
# 21st label is jute!

data = np.array([[83, 45, 60, 28, 70.3, 7.0, 150.9]])
prediction = svc.predict(data)
pred = prediction[0]
print(labels_map_new[pred])


data = np.array([[104,18, 30, 23.603016, 60.3, 6.7, 140.91]])
prediction = svc.predict(data)
pred = prediction[0]
print(labels_map_new[pred])
# Out:
# jute
# coffee
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# C:\Users\user2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Saving the Model

# %%
import pickle
svm_model_pkl = open('crop_classification_model.pkl', 'wb')
pickle.dump(svc, svm_model_pkl)
svm_model_pkl.close()

# %%
file = open('cropmodel2.pkl','wb')
pickle.dump(svc,file)
file.close()
